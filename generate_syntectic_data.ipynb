# %% [markdown]
# python version:
# ```
# Python 3.8.10
#
# ```

# %% [markdown]
# Intalacion ambiente virtual:

# %% [markdown]
# ```
# python -m virtualenv -p="C:\Users\1061708930\AppData\Local\Programs\Python\Python3.8.10\python.exe" venv
# ```

# %% [markdown]
# Activacion ambiente virtual:

# %% [markdown]
# ```
# .\venv\Scripts\activate
# ```

# %% [markdown]
# Libraries: pip install -r requirements

# %% [markdown]
# ```
# comm==0.1.3
# drawdata==0.2.0
# ipython==8.12.2
# ipywidgets==8.0.7
# matplotlib==3.7.2
# numpy==1.24.4
# pandas==2.0.3
# seaborn==0.12.2
# ```

# %%
from drawdata import draw_scatter
import pandas as pd 
import seaborn as sns
from matplotlib import pyplot as plt

# %%
draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df=pd.read_clipboard(sep=",")
df
# Out:
#               x           y  z
# 0    116.925775  430.640135  d
# 1    105.939492  374.725109  d
# 2    128.363959  391.328602  d
# 3     86.930604  388.070358  d
# 4     77.521365  407.516800  d
# ..          ...         ... ..
# 758  296.467833  142.094582  c
# 759  297.735059  184.348915  c
# 760  289.557062  134.368156  c
# 761  336.558205  137.262789  c
# 762  286.906587  111.202871  c
#
# [763 rows x 3 columns]

# %%
sns.scatterplot(data=df, x="x", y="y", hue="z")
plt.show()
